# %% [markdown]
# # Exploratory  Data Analysis : 2019

# %% [markdown]
# ## Import relevant Packages

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing the data from Data from DW step

# %%
df_2019=pd.read_csv('Data/2019_dw_data.csv')

# %%
#Exploring the data
df_2019.head().transpose()
# Out:
#                                        0        1        2        3        4
# Unnamed: 0                             0        1        2        3        4
# Year                                2019     2019     2019     2019     2019
# LoanCharacteristicsID            2407198  2407199  2407200  2407201  2407202
# Bank                              Boston   Boston   Boston   Boston   Boston
# FIPSStateNumericCode                  50       50       50       50       23
# FIPSCountyCode                         7        7       15       17       31
# CoreBasedStatisticalAreaCode       15540    15540    99999    30100    38860
# CensusTractIdentifier                 34       29     9532     9594      254
# CensusTractMinorityRatioPercent    4.577    3.421    6.152    3.935    6.031
# CensusTractMedFamIncomeAmount     132474   100795    49625    62643    87679
# LocalAreaMedianIncomeAmount        84290    84290    67566    67105    76445
# TotalMonthlyIncomeAmount            7308     7416     5143     8866    15240
# HUDMedianIncomeAmount              93000    93000    71900    71900    90100
# LoanAcquisitionActualUPBAmt       319113   248005   211105   210000   233200
# LTVRatioPercent                       99       97       99      100       80
# NoteDate                            2018     2019     2018     2018     2018
# LoanAcquistionDate                  2019     2019     2019     2019     2019
# LoanPurposeType                        1        1        1        1        1
# ProductCategoryName                    1        1        1        1        1
# MortgageType                           1        1        1        2        0
# ScheduledTotalPaymentCount           360      360      360      360      180
# MortgageLoanSellerInstType             1        1        1        1        1
# BorrowerCount                          1        2        2        2        1
# BorrowerFirstTimeHomebuyer             1        0        0        0        1
# Borrower1Race1Type                     5        5        5        5        5
# Borrower2Race1Type                     8        5        5        5        8
# Borrower1GenderType                    2        2        1        1        2
# Borrower2GenderType                    4        1        2        2        4
# Borrower1AgeAtApplicationYears        34       36       34       42       66
# Borrower2AgeAtApplicationYears       998       33       36       43      998
# PropertyUsageType                      1        1        1        1        1
# PropertyUnitCount                      1        1        1        1        1
# NoteRatePercent                        4     4.25     4.25    4.875    4.625
# NoteAmount                        319113   248005   211105   210000   233200
# HousingExpenseRatioPercent         30.17    25.42    28.42    17.46    14.85
# TotalDebtExpenseRatioPercent       40.46    45.67    46.23    36.88    34.95
# Borrower1CreditScoreValue              1        3        2        4        5
# Borrower2CreditScoreValue              9        2        3        2        9
# PMICoveragePercent                     0        0        0        0        0
# EmploymentBorrowerSelfEmployed         1        1        1        1        1
# PropertyType                        PT01     PT01     PT01     PT01     PT01
# IndexSourceType                       99       99       99       99       99
# MarginRatePercent                   9999     9999     9999     9999     9999
# Borrower1EthnicityType                 2        2        2        2        2
# Borrower1Race2Type                     7        7        7        7        7
# Borrower1Race3Type                     7        7        7        7        7
# Borrower1Race4Type                     7        7        7        7        7
# Borrower1Race5Type                     7        7        7        7        7
# Borrower2EthnicityType                 5        2        2        2        5
# Borrower2Race2Type                     8        7        7        7        8
# Borrower2Race3Type                     8        7        7        7        8
# Borrower2Race4Type                     8        7        7        7        8
# Borrower2Race5Type                     8        7        7        7        8
# HOEPALoanStatusType                    2        2        2        2        2
# LienPriorityType                       1        1        1        1        1

# %%
#Drop Unnamed:0 column
df_2019=df_2019.iloc[:,1:]

# %%
#Check the shape of the DataFrame
df_2019.shape
# Out:
# (89767, 54)

# %%
#'LoanAcquisitionActualUPBAmt' and 'NoteAmount' seems to be duplicate lets check it. 
np.sum(df_2019['LoanAcquisitionActualUPBAmt']== df_2019['NoteAmount'])
# Out:
# 77406

# %% [markdown]
# Hence there are some values where two columns have not the same value. Lets check the rows where both have not same values.

# %%
df_2019[df_2019['LoanAcquisitionActualUPBAmt']!= df_2019['NoteAmount']].transpose()
# Out:
#                                    19       20       69       70       72     \
# Year                                2019     2019     2019     2019     2019
# LoanCharacteristicsID            2407217  2407218  2407267  2407268  2407270
# Bank                              Boston   Boston   Boston   Boston   Boston
# FIPSStateNumericCode                  25       12       23       23       23
# FIPSCountyCode                        21       86        5        5       17
# CoreBasedStatisticalAreaCode       14460    33100    38860    38860    99999
# CensusTractIdentifier               4224      195   171.02    25.02     9665
# CensusTractMinorityRatioPercent   13.436   81.648    2.284    5.653    4.627
# CensusTractMedFamIncomeAmount     105577    69580    81856   120577    42143
# LocalAreaMedianIncomeAmount        98431    58757    76445    76445    57050
# TotalMonthlyIncomeAmount           10874     9505     9581    17104     2894
# HUDMedianIncomeAmount             107800    65700    90100    90100    60200
# LoanAcquisitionActualUPBAmt       273670   264845   178121   374483   119841
# LTVRatioPercent                       70       90       80       73       69
# NoteDate                            2018     2018     2018     2019     2019
# LoanAcquistionDate                  2019     2019     2019     2019     2019
# LoanPurposeType                        6        1        1        6        1
# ProductCategoryName                    1        1        1        1        1
# MortgageType                           0        0        0        0        0
# ScheduledTotalPaymentCount           360      360      360      360      360
# MortgageLoanSellerInstType             1        1        1        1        1
# BorrowerCount                          2        1        2        2        1
# BorrowerFirstTimeHomebuyer             1        0        1        1        1
# Borrower1Race1Type                     5        3        5        6        5
# Borrower2Race1Type                     5        8        5        6        8
# Borrower1GenderType                    1        1        2        1        2
# Borrower2GenderType                    2        4        1        2        4
# Borrower1AgeAtApplicationYears        44       39       41       61       50
# Borrower2AgeAtApplicationYears        40      998       52       65      998
# PropertyUsageType                      1        2        1        1        1
# PropertyUnitCount                      2        1        1        1        1
# NoteRatePercent                        5    4.875    4.625     4.25      4.5
# NoteAmount                        274000   265500   180000   375000   120000
# HousingExpenseRatioPercent         18.37    18.94    12.01    14.59    31.12
# TotalDebtExpenseRatioPercent       25.77     47.4    16.58    45.51    31.12
# Borrower1CreditScoreValue              4        5        5        4        5
# Borrower2CreditScoreValue              4        9        5        4        9
# PMICoveragePercent                     0       25        0        0        0
# EmploymentBorrowerSelfEmployed         1        1        1        0        1
# PropertyType                        PT04     PT07     PT01     PT01     PT01
# IndexSourceType                       99       99       99       99       99
# MarginRatePercent                   9999     9999     9999     9999     9999
# Borrower1EthnicityType                 2        2        2        3        2
# Borrower1Race2Type                     7        7        7        7        7
# Borrower1Race3Type                     7        7        7        7        7
# Borrower1Race4Type                     7        7        7        7        7
# Borrower1Race5Type                     7        7        7        7        7
# Borrower2EthnicityType                 2        5        2        2        5
# Borrower2Race2Type                     7        8        7        7        8
# Borrower2Race3Type                     7        8        7        7        8
# Borrower2Race4Type                     7        8        7        7        8
# Borrower2Race5Type                     7        8        7        7        8
# HOEPALoanStatusType                    2        2        2        2        2
# LienPriorityType                       1        1        1        1        1
#
#                                    73       90       91       92       94     \
# Year                                2019     2019     2019     2019     2019
# LoanCharacteristicsID            2407271  2407288  2407289  2407290  2407292
# Bank                              Boston   Boston   Boston   Boston   Boston
# FIPSStateNumericCode                  23       25        9       25        9
# FIPSCountyCode                         5       13        3       27       13
# CoreBasedStatisticalAreaCode       38860    44140    25540    49340    25540
# CensusTractIdentifier              40.02  8016.04     4761     7371     8601
# CensusTractMinorityRatioPercent    4.384   23.573   20.438    6.314    5.141
# CensusTractMedFamIncomeAmount      87240    79615    76520   107400   103352
# LocalAreaMedianIncomeAmount        76445    69235    90197    83776    90197
# TotalMonthlyIncomeAmount           12580     3547     8418    12200    10008
# HUDMedianIncomeAmount              90100    73900    96600    85800    96600
# LoanAcquisitionActualUPBAmt       395501   183286   314205   378973   277713
# LTVRatioPercent                       80       80       90       72       80
# NoteDate                            2019     2018     2018     2018     2018
# LoanAcquistionDate                  2019     2019     2019     2019     2019
# LoanPurposeType                        1        1        1        1        1
# ProductCategoryName                    1        1        1        1        1
# MortgageType                           0        0        0        0        0
# ScheduledTotalPaymentCount           360      360      360      360      360
# MortgageLoanSellerInstType             1        1        1        1        1
# BorrowerCount                          2        1        2        2        2
# BorrowerFirstTimeHomebuyer             1        1        1        0        1
# Borrower1Race1Type                     5        3        3        5        5
# Borrower2Race1Type                     5        8        3        5        5
# Borrower1GenderType                    2        2        1        1        1
# Borrower2GenderType                    1        4        2        2        2
# Borrower1AgeAtApplicationYears        35       53       61       59       62
# Borrower2AgeAtApplicationYears        34      998       60       56       36
# PropertyUsageType                      1        1        1        1        1
# PropertyUnitCount                      1        1        1        1        1
# NoteRatePercent                     4.75    4.625     4.75    4.625    4.875
# NoteAmount                        396000   184000   315000   379954   278400
# HousingExpenseRatioPercent         22.28    40.53    29.66    22.55    23.65
# TotalDebtExpenseRatioPercent       24.87    45.92     44.8    49.28    49.92
# Borrower1CreditScoreValue              5        5        4        5        5
# Borrower2CreditScoreValue              5        9        5        5        4
# PMICoveragePercent                     0        0       25        0        0
# EmploymentBorrowerSelfEmployed         1        1        1        0        1
# PropertyType                        PT01     PT01     PT07     PT01     PT01
# IndexSourceType                       99       99       99       99       99
# MarginRatePercent                   9999     9999     9999     9999     9999
# Borrower1EthnicityType                 2        2        2        2        2
# Borrower1Race2Type                     7        7        7        7        7
# Borrower1Race3Type                     7        7        7        7        7
# Borrower1Race4Type                     7        7        7        7        7
# Borrower1Race5Type                     7        7        7        7        7
# Borrower2EthnicityType                 2        5        2        2        2
# Borrower2Race2Type                     7        8        7        7        7
# Borrower2Race3Type                     7        8        7        7        7
# Borrower2Race4Type                     7        8        7        7        7
# Borrower2Race5Type                     7        8        7        7        7
# HOEPALoanStatusType                    2        2        2        2        2
# LienPriorityType                       1        1        1        1        1
#
#                                  ...    89034    89332    89543    89545  \
# Year                             ...     2019     2019     2019     2019
# LoanCharacteristicsID            ...  2491238  2491536  2491747  2491749
# Bank                             ...   Topeka   Topeka   Topeka   Topeka
# FIPSStateNumericCode             ...       20       31        8        4
# FIPSCountyCode                   ...       91       55       31       13
# CoreBasedStatisticalAreaCode     ...    28140    36540    19740    38060
# CensusTractIdentifier            ...   526.01    67.01    37.03     8156
# CensusTractMinorityRatioPercent  ...   10.713    11.33   22.706   32.047
# CensusTractMedFamIncomeAmount    ...   132366   147969   122500    97267
# LocalAreaMedianIncomeAmount      ...    77634    79131    88102    68709
# TotalMonthlyIncomeAmount         ...    16712     8587    19077    14361
# HUDMedianIncomeAmount            ...    82400    86100    92800    72900
# LoanAcquisitionActualUPBAmt      ...   481499   189214   544165   446696
# LTVRatioPercent                  ...       90       38       65      100
# NoteDate                         ...     2019     2019     2019     2019
# LoanAcquistionDate               ...     2019     2019     2019     2019
# LoanPurposeType                  ...        1        6        2        2
# ProductCategoryName              ...        1        1        1        1
# MortgageType                     ...        0        0        0        2
# ScheduledTotalPaymentCount       ...      360      360      360      360
# MortgageLoanSellerInstType       ...        1        1        1        1
# BorrowerCount                    ...        2        1        2        2
# BorrowerFirstTimeHomebuyer       ...        0        0        0        0
# Borrower1Race1Type               ...        5        5        5        5
# Borrower2Race1Type               ...        5        8        5        5
# Borrower1GenderType              ...        1        1        1        1
# Borrower2GenderType              ...        2        4        2        2
# Borrower1AgeAtApplicationYears   ...       36       35       44       52
# Borrower2AgeAtApplicationYears   ...       40      998       42       54
# PropertyUsageType                ...        1        1        1        1
# PropertyUnitCount                ...        1        1        1        1
# NoteRatePercent                  ...    3.625    4.625    3.625      3.5
# NoteAmount                       ...   481500   190450   545100   448109
# HousingExpenseRatioPercent       ...       20    25.18    15.75    14.68
# TotalDebtExpenseRatioPercent     ...    36.18    49.16    24.96    17.27
# Borrower1CreditScoreValue        ...        4        5        5        5
# Borrower2CreditScoreValue        ...        4        9        5        5
# PMICoveragePercent               ...       30        0        0        0
# EmploymentBorrowerSelfEmployed   ...        0        0        0        0
# PropertyType                     ...     PT07     PT01     PT01     PT01
# IndexSourceType                  ...       99       99       99       99
# MarginRatePercent                ...     9999     9999     9999     9999
# Borrower1EthnicityType           ...        2        2        2        2
# Borrower1Race2Type               ...        7        7        7        7
# Borrower1Race3Type               ...        7        7        7        7
# Borrower1Race4Type               ...        7        7        7        7
# Borrower1Race5Type               ...        7        7        7        7
# Borrower2EthnicityType           ...        2        5        2        2
# Borrower2Race2Type               ...        7        8        7        7
# Borrower2Race3Type               ...        7        8        7        7
# Borrower2Race4Type               ...        7        8        7        7
# Borrower2Race5Type               ...        7        8        7        7
# HOEPALoanStatusType              ...        2        2        2        2
# LienPriorityType                 ...        1        1        1        1
#
#                                    89553    89569    89572    89574    89575  \
# Year                                2019     2019     2019     2019     2019
# LoanCharacteristicsID            2491757  2491773  2491776  2491778  2491779
# Bank                              Topeka   Topeka   Topeka   Topeka   Topeka
# FIPSStateNumericCode                   8        8        8        8        8
# FIPSCountyCode                       117       59       35        5       35
# CoreBasedStatisticalAreaCode       14720    19740    19740    19740    19740
# CensusTractIdentifier               4.01   120.27   141.27    68.54   140.07
# CensusTractMinorityRatioPercent   11.472    5.522    12.51   26.018   25.353
# CensusTractMedFamIncomeAmount      90379   116842   163750   104028    77000
# LocalAreaMedianIncomeAmount        90271    88102    88102    88102    88102
# TotalMonthlyIncomeAmount           63576    22666     8798    10587     7083
# HUDMedianIncomeAmount              89100    92800    92800    92800    92800
# LoanAcquisitionActualUPBAmt       594283   548135   387425   542291   327264
# LTVRatioPercent                       62       70       74       74       95
# NoteDate                            2019     2019     2019     2019     2019
# LoanAcquistionDate                  2019     2019     2019     2019     2019
# LoanPurposeType                        2        1        6        6        1
# ProductCategoryName                    1        1        1        1        1
# MortgageType                           0        0        0        0        0
# ScheduledTotalPaymentCount           360      360      359      360      359
# MortgageLoanSellerInstType             1        1        1        1        1
# BorrowerCount                          1        2        2        2        1
# BorrowerFirstTimeHomebuyer             0        0        0        0        1
# Borrower1Race1Type                     5        5        5        5        2
# Borrower2Race1Type                     8        5        5        5        8
# Borrower1GenderType                    1        1        1        1        1
# Borrower2GenderType                    4        2        2        2        4
# Borrower1AgeAtApplicationYears        44       42       55       65       28
# Borrower2AgeAtApplicationYears       998       41       51       58      998
# PropertyUsageType                      2        1        1        1        1
# PropertyUnitCount                      1        1        1        1        1
# NoteRatePercent                    3.625      3.5    3.875     4.55    3.875
# NoteAmount                        595200   549000   388000   543000   327750
# HousingExpenseRatioPercent          3.64    14.37    26.94    30.41    30.25
# TotalDebtExpenseRatioPercent       24.56    16.65    48.21    39.07    34.88
# Borrower1CreditScoreValue              5        5        4        5        4
# Borrower2CreditScoreValue              9        5        5        5        9
# PMICoveragePercent                     0        0        0        0       30
# EmploymentBorrowerSelfEmployed         1        0        1        1        0
# PropertyType                        PT06     PT07     PT07     PT07     PT06
# IndexSourceType                       99       99       99       99       99
# MarginRatePercent                   9999     9999     9999     9999     9999
# Borrower1EthnicityType                 2        2        2        2        2
# Borrower1Race2Type                     7        7        7        7        7
# Borrower1Race3Type                     7        7        7        7        7
# Borrower1Race4Type                     7        7        7        7        7
# Borrower1Race5Type                     7        7        7        7        7
# Borrower2EthnicityType                 5        2        2        2        5
# Borrower2Race2Type                     8        7        7        7        8
# Borrower2Race3Type                     8        7        7        7        8
# Borrower2Race4Type                     8        7        7        7        8
# Borrower2Race5Type                     8        7        7        7        8
# HOEPALoanStatusType                    2        2        2        2        2
# LienPriorityType                       1        1        1        1        1
#
#                                    89576
# Year                                2019
# LoanCharacteristicsID            2491780
# Bank                              Topeka
# FIPSStateNumericCode                   8
# FIPSCountyCode                        39
# CoreBasedStatisticalAreaCode       19740
# CensusTractIdentifier            9612.04
# CensusTractMinorityRatioPercent   10.812
# CensusTractMedFamIncomeAmount     119531
# LocalAreaMedianIncomeAmount        88102
# TotalMonthlyIncomeAmount            8517
# HUDMedianIncomeAmount              92800
# LoanAcquisitionActualUPBAmt       401920
# LTVRatioPercent                       70
# NoteDate                            2019
# LoanAcquistionDate                  2019
# LoanPurposeType                        1
# ProductCategoryName                    1
# MortgageType                           0
# ScheduledTotalPaymentCount           360
# MortgageLoanSellerInstType             1
# BorrowerCount                          2
# BorrowerFirstTimeHomebuyer             0
# Borrower1Race1Type                     5
# Borrower2Race1Type                     5
# Borrower1GenderType                    2
# Borrower2GenderType                    1
# Borrower1AgeAtApplicationYears        43
# Borrower2AgeAtApplicationYears        52
# PropertyUsageType                      1
# PropertyUnitCount                      1
# NoteRatePercent                        4
# NoteAmount                        402500
# HousingExpenseRatioPercent         26.91
# TotalDebtExpenseRatioPercent       45.13
# Borrower1CreditScoreValue              5
# Borrower2CreditScoreValue              3
# PMICoveragePercent                     0
# EmploymentBorrowerSelfEmployed         0
# PropertyType                        PT01
# IndexSourceType                       99
# MarginRatePercent                   9999
# Borrower1EthnicityType                 2
# Borrower1Race2Type                     7
# Borrower1Race3Type                     7
# Borrower1Race4Type                     7
# Borrower1Race5Type                     7
# Borrower2EthnicityType                 2
# Borrower2Race2Type                     7
# Borrower2Race3Type                     7
# Borrower2Race4Type                     7
# Borrower2Race5Type                     7
# HOEPALoanStatusType                    2
# LienPriorityType                       1
#
# [54 rows x 12361 columns]

# %% [markdown]
# It looks like both columns have approx same values. Lets check if this fact by subtracting LoanAcquisitionActualUPBAmt column from NoteAmount and check if the difference is less than 500.

# %%
df_2019[df_2019['NoteAmount']-df_2019['LoanAcquisitionActualUPBAmt']>500].transpose()
# Out:
#                                    20       69       70       90       91     \
# Year                                2019     2019     2019     2019     2019
# LoanCharacteristicsID            2407218  2407267  2407268  2407288  2407289
# Bank                              Boston   Boston   Boston   Boston   Boston
# FIPSStateNumericCode                  12       23       23       25        9
# FIPSCountyCode                        86        5        5       13        3
# CoreBasedStatisticalAreaCode       33100    38860    38860    44140    25540
# CensusTractIdentifier                195   171.02    25.02  8016.04     4761
# CensusTractMinorityRatioPercent   81.648    2.284    5.653   23.573   20.438
# CensusTractMedFamIncomeAmount      69580    81856   120577    79615    76520
# LocalAreaMedianIncomeAmount        58757    76445    76445    69235    90197
# TotalMonthlyIncomeAmount            9505     9581    17104     3547     8418
# HUDMedianIncomeAmount              65700    90100    90100    73900    96600
# LoanAcquisitionActualUPBAmt       264845   178121   374483   183286   314205
# LTVRatioPercent                       90       80       73       80       90
# NoteDate                            2018     2018     2019     2018     2018
# LoanAcquistionDate                  2019     2019     2019     2019     2019
# LoanPurposeType                        1        1        6        1        1
# ProductCategoryName                    1        1        1        1        1
# MortgageType                           0        0        0        0        0
# ScheduledTotalPaymentCount           360      360      360      360      360
# MortgageLoanSellerInstType             1        1        1        1        1
# BorrowerCount                          1        2        2        1        2
# BorrowerFirstTimeHomebuyer             0        1        1        1        1
# Borrower1Race1Type                     3        5        6        3        3
# Borrower2Race1Type                     8        5        6        8        3
# Borrower1GenderType                    1        2        1        2        1
# Borrower2GenderType                    4        1        2        4        2
# Borrower1AgeAtApplicationYears        39       41       61       53       61
# Borrower2AgeAtApplicationYears       998       52       65      998       60
# PropertyUsageType                      2        1        1        1        1
# PropertyUnitCount                      1        1        1        1        1
# NoteRatePercent                    4.875    4.625     4.25    4.625     4.75
# NoteAmount                        265500   180000   375000   184000   315000
# HousingExpenseRatioPercent         18.94    12.01    14.59    40.53    29.66
# TotalDebtExpenseRatioPercent        47.4    16.58    45.51    45.92     44.8
# Borrower1CreditScoreValue              5        5        4        5        4
# Borrower2CreditScoreValue              9        5        4        9        5
# PMICoveragePercent                    25        0        0        0       25
# EmploymentBorrowerSelfEmployed         1        1        0        1        1
# PropertyType                        PT07     PT01     PT01     PT01     PT07
# IndexSourceType                       99       99       99       99       99
# MarginRatePercent                   9999     9999     9999     9999     9999
# Borrower1EthnicityType                 2        2        3        2        2
# Borrower1Race2Type                     7        7        7        7        7
# Borrower1Race3Type                     7        7        7        7        7
# Borrower1Race4Type                     7        7        7        7        7
# Borrower1Race5Type                     7        7        7        7        7
# Borrower2EthnicityType                 5        2        2        5        2
# Borrower2Race2Type                     8        7        7        8        7
# Borrower2Race3Type                     8        7        7        8        7
# Borrower2Race4Type                     8        7        7        8        7
# Borrower2Race5Type                     8        7        7        8        7
# HOEPALoanStatusType                    2        2        2        2        2
# LienPriorityType                       1        1        1        1        1
#
#                                    92       94       95       98       100    \
# Year                                2019     2019     2019     2019     2019
# LoanCharacteristicsID            2407290  2407292  2407293  2407296  2407298
# Bank                              Boston   Boston   Boston   Boston   Boston
# FIPSStateNumericCode                  25        9        9        9       25
# FIPSCountyCode                        27       13       13       13       27
# CoreBasedStatisticalAreaCode       49340    25540    25540    25540    49340
# CensusTractIdentifier               7371     8601     8501     8501  7322.02
# CensusTractMinorityRatioPercent    6.314    5.141     5.36     5.36   28.704
# CensusTractMedFamIncomeAmount     107400   103352   102232   102232    46674
# LocalAreaMedianIncomeAmount        83776    90197    90197    90197    83776
# TotalMonthlyIncomeAmount           12200    10008    16442    11648     6423
# HUDMedianIncomeAmount              85800    96600    96600    96600    85800
# LoanAcquisitionActualUPBAmt       378973   277713   378525   326416   340834
# LTVRatioPercent                       72       80       95       80       99
# NoteDate                            2018     2018     2018     2018     2018
# LoanAcquistionDate                  2019     2019     2019     2019     2019
# LoanPurposeType                        1        1        1        1        1
# ProductCategoryName                    1        1        1        1        1
# MortgageType                           0        0        0        0        1
# ScheduledTotalPaymentCount           360      360      360      360      360
# MortgageLoanSellerInstType             1        1        1        1        1
# BorrowerCount                          2        2        2        2        2
# BorrowerFirstTimeHomebuyer             0        1        1        1        0
# Borrower1Race1Type                     5        5        5        5        5
# Borrower2Race1Type                     5        5        5        5        5
# Borrower1GenderType                    1        1        1        2        2
# Borrower2GenderType                    2        2        2        1        1
# Borrower1AgeAtApplicationYears        59       62       27       37       40
# Borrower2AgeAtApplicationYears        56       36       27       38       34
# PropertyUsageType                      1        1        1        1        1
# PropertyUnitCount                      1        1        1        1        2
# NoteRatePercent                    4.625    4.875    4.625      4.5     4.75
# NoteAmount                        379954   278400   380000   327280   341696
# HousingExpenseRatioPercent         22.55    23.65    17.48    20.53    39.49
# TotalDebtExpenseRatioPercent       49.28    49.92    32.94    21.58    47.08
# Borrower1CreditScoreValue              5        5        4        5        4
# Borrower2CreditScoreValue              5        4        5        5        4
# PMICoveragePercent                     0        0       30        0        0
# EmploymentBorrowerSelfEmployed         0        1        1        1        1
# PropertyType                        PT01     PT01     PT01     PT01     PT04
# IndexSourceType                       99       99       99       99       99
# MarginRatePercent                   9999     9999     9999     9999     9999
# Borrower1EthnicityType                 2        2        2        2        1
# Borrower1Race2Type                     7        7        7        7        7
# Borrower1Race3Type                     7        7        7        7        7
# Borrower1Race4Type                     7        7        7        7        7
# Borrower1Race5Type                     7        7        7        7        7
# Borrower2EthnicityType                 2        2        2        2        1
# Borrower2Race2Type                     7        7        7        7        7
# Borrower2Race3Type                     7        7        7        7        7
# Borrower2Race4Type                     7        7        7        7        7
# Borrower2Race5Type                     7        7        7        7        7
# HOEPALoanStatusType                    2        2        2        2        2
# LienPriorityType                       1        1        1        1        1
#
#                                  ...    88984    88990    89332    89543  \
# Year                             ...     2019     2019     2019     2019
# LoanCharacteristicsID            ...  2491188  2491194  2491536  2491747
# Bank                             ...   Topeka   Topeka   Topeka   Topeka
# FIPSStateNumericCode             ...       20       20       31        8
# FIPSCountyCode                   ...      173      155       55       31
# CoreBasedStatisticalAreaCode     ...    48620    26740    36540    19740
# CensusTractIdentifier            ...      103       11    67.01    37.03
# CensusTractMinorityRatioPercent  ...    14.47    9.777    11.33   22.706
# CensusTractMedFamIncomeAmount    ...   104280    80313   147969   122500
# LocalAreaMedianIncomeAmount      ...    68171    60187    79131    88102
# TotalMonthlyIncomeAmount         ...    10508     5667     8587    19077
# HUDMedianIncomeAmount            ...    72800    61500    86100    92800
# LoanAcquisitionActualUPBAmt      ...   262099   184000   189214   544165
# LTVRatioPercent                  ...       61       70       38       65
# NoteDate                         ...     2019     2019     2019     2019
# LoanAcquistionDate               ...     2019     2019     2019     2019
# LoanPurposeType                  ...        2        2        6        2
# ProductCategoryName              ...        1        1        1        1
# MortgageType                     ...        0        0        0        0
# ScheduledTotalPaymentCount       ...      240      180      360      360
# MortgageLoanSellerInstType       ...        1        1        1        1
# BorrowerCount                    ...        2        2        1        2
# BorrowerFirstTimeHomebuyer       ...        0        0        0        0
# Borrower1Race1Type               ...        5        5        5        5
# Borrower2Race1Type               ...        5        5        8        5
# Borrower1GenderType              ...        1        1        1        1
# Borrower2GenderType              ...        2        2        4        2
# Borrower1AgeAtApplicationYears   ...       41       43       35       44
# Borrower2AgeAtApplicationYears   ...       41       43      998       42
# PropertyUsageType                ...        1        1        1        1
# PropertyUnitCount                ...        1        1        1        1
# NoteRatePercent                  ...      3.5     3.25    4.625    3.625
# NoteAmount                       ...   262900   186000   190450   545100
# HousingExpenseRatioPercent       ...    25.25    34.75    25.18    15.75
# TotalDebtExpenseRatioPercent     ...     43.4    36.28    49.16    24.96
# Borrower1CreditScoreValue        ...        5        5        5        5
# Borrower2CreditScoreValue        ...        5        5        9        5
# PMICoveragePercent               ...        0        0        0        0
# EmploymentBorrowerSelfEmployed   ...        0        0        0        0
# PropertyType                     ...     PT01     PT01     PT01     PT01
# IndexSourceType                  ...       99       99       99       99
# MarginRatePercent                ...     9999     9999     9999     9999
# Borrower1EthnicityType           ...        2        2        2        2
# Borrower1Race2Type               ...        7        7        7        7
# Borrower1Race3Type               ...        7        7        7        7
# Borrower1Race4Type               ...        7        7        7        7
# Borrower1Race5Type               ...        7        7        7        7
# Borrower2EthnicityType           ...        2        2        5        2
# Borrower2Race2Type               ...        7        7        8        7
# Borrower2Race3Type               ...        7        7        8        7
# Borrower2Race4Type               ...        7        7        8        7
# Borrower2Race5Type               ...        7        7        8        7
# HOEPALoanStatusType              ...        2        2        2        2
# LienPriorityType                 ...        1        1        1        1
#
#                                    89545    89553    89569    89572    89574  \
# Year                                2019     2019     2019     2019     2019
# LoanCharacteristicsID            2491749  2491757  2491773  2491776  2491778
# Bank                              Topeka   Topeka   Topeka   Topeka   Topeka
# FIPSStateNumericCode                   4        8        8        8        8
# FIPSCountyCode                        13      117       59       35        5
# CoreBasedStatisticalAreaCode       38060    14720    19740    19740    19740
# CensusTractIdentifier               8156     4.01   120.27   141.27    68.54
# CensusTractMinorityRatioPercent   32.047   11.472    5.522    12.51   26.018
# CensusTractMedFamIncomeAmount      97267    90379   116842   163750   104028
# LocalAreaMedianIncomeAmount        68709    90271    88102    88102    88102
# TotalMonthlyIncomeAmount           14361    63576    22666     8798    10587
# HUDMedianIncomeAmount              72900    89100    92800    92800    92800
# LoanAcquisitionActualUPBAmt       446696   594283   548135   387425   542291
# LTVRatioPercent                      100       62       70       74       74
# NoteDate                            2019     2019     2019     2019     2019
# LoanAcquistionDate                  2019     2019     2019     2019     2019
# LoanPurposeType                        2        2        1        6        6
# ProductCategoryName                    1        1        1        1        1
# MortgageType                           2        0        0        0        0
# ScheduledTotalPaymentCount           360      360      360      359      360
# MortgageLoanSellerInstType             1        1        1        1        1
# BorrowerCount                          2        1        2        2        2
# BorrowerFirstTimeHomebuyer             0        0        0        0        0
# Borrower1Race1Type                     5        5        5        5        5
# Borrower2Race1Type                     5        8        5        5        5
# Borrower1GenderType                    1        1        1        1        1
# Borrower2GenderType                    2        4        2        2        2
# Borrower1AgeAtApplicationYears        52       44       42       55       65
# Borrower2AgeAtApplicationYears        54      998       41       51       58
# PropertyUsageType                      1        2        1        1        1
# PropertyUnitCount                      1        1        1        1        1
# NoteRatePercent                      3.5    3.625      3.5    3.875     4.55
# NoteAmount                        448109   595200   549000   388000   543000
# HousingExpenseRatioPercent         14.68     3.64    14.37    26.94    30.41
# TotalDebtExpenseRatioPercent       17.27    24.56    16.65    48.21    39.07
# Borrower1CreditScoreValue              5        5        5        4        5
# Borrower2CreditScoreValue              5        9        5        5        5
# PMICoveragePercent                     0        0        0        0        0
# EmploymentBorrowerSelfEmployed         0        1        0        1        1
# PropertyType                        PT01     PT06     PT07     PT07     PT07
# IndexSourceType                       99       99       99       99       99
# MarginRatePercent                   9999     9999     9999     9999     9999
# Borrower1EthnicityType                 2        2        2        2        2
# Borrower1Race2Type                     7        7        7        7        7
# Borrower1Race3Type                     7        7        7        7        7
# Borrower1Race4Type                     7        7        7        7        7
# Borrower1Race5Type                     7        7        7        7        7
# Borrower2EthnicityType                 2        5        2        2        2
# Borrower2Race2Type                     7        8        7        7        7
# Borrower2Race3Type                     7        8        7        7        7
# Borrower2Race4Type                     7        8        7        7        7
# Borrower2Race5Type                     7        8        7        7        7
# HOEPALoanStatusType                    2        2        2        2        2
# LienPriorityType                       1        1        1        1        1
#
#                                    89576
# Year                                2019
# LoanCharacteristicsID            2491780
# Bank                              Topeka
# FIPSStateNumericCode                   8
# FIPSCountyCode                        39
# CoreBasedStatisticalAreaCode       19740
# CensusTractIdentifier            9612.04
# CensusTractMinorityRatioPercent   10.812
# CensusTractMedFamIncomeAmount     119531
# LocalAreaMedianIncomeAmount        88102
# TotalMonthlyIncomeAmount            8517
# HUDMedianIncomeAmount              92800
# LoanAcquisitionActualUPBAmt       401920
# LTVRatioPercent                       70
# NoteDate                            2019
# LoanAcquistionDate                  2019
# LoanPurposeType                        1
# ProductCategoryName                    1
# MortgageType                           0
# ScheduledTotalPaymentCount           360
# MortgageLoanSellerInstType             1
# BorrowerCount                          2
# BorrowerFirstTimeHomebuyer             0
# Borrower1Race1Type                     5
# Borrower2Race1Type                     5
# Borrower1GenderType                    2
# Borrower2GenderType                    1
# Borrower1AgeAtApplicationYears        43
# Borrower2AgeAtApplicationYears        52
# PropertyUsageType                      1
# PropertyUnitCount                      1
# NoteRatePercent                        4
# NoteAmount                        402500
# HousingExpenseRatioPercent         26.91
# TotalDebtExpenseRatioPercent       45.13
# Borrower1CreditScoreValue              5
# Borrower2CreditScoreValue              3
# PMICoveragePercent                     0
# EmploymentBorrowerSelfEmployed         0
# PropertyType                        PT01
# IndexSourceType                       99
# MarginRatePercent                   9999
# Borrower1EthnicityType                 2
# Borrower1Race2Type                     7
# Borrower1Race3Type                     7
# Borrower1Race4Type                     7
# Borrower1Race5Type                     7
# Borrower2EthnicityType                 2
# Borrower2Race2Type                     7
# Borrower2Race3Type                     7
# Borrower2Race4Type                     7
# Borrower2Race5Type                     7
# HOEPALoanStatusType                    2
# LienPriorityType                       1
#
# [54 rows x 6522 columns]

# %% [markdown]
# Hence there are significant number of values where both columns have not 'approximatly' same value. Therefore I will not drop one of the columns.

# %%
#Check the dtypes of the data
df_2019.dtypes
# Out:
# Year                                 int64
# LoanCharacteristicsID                int64
# Bank                                object
# FIPSStateNumericCode                 int64
# FIPSCountyCode                       int64
# CoreBasedStatisticalAreaCode         int64
# CensusTractIdentifier              float64
# CensusTractMinorityRatioPercent    float64
# CensusTractMedFamIncomeAmount        int64
# LocalAreaMedianIncomeAmount          int64
# TotalMonthlyIncomeAmount             int64
# HUDMedianIncomeAmount                int64
# LoanAcquisitionActualUPBAmt          int64
# LTVRatioPercent                    float64
# NoteDate                             int64
# LoanAcquistionDate                   int64
# LoanPurposeType                      int64
# ProductCategoryName                  int64
# MortgageType                         int64
# ScheduledTotalPaymentCount           int64
# MortgageLoanSellerInstType           int64
# BorrowerCount                        int64
# BorrowerFirstTimeHomebuyer           int64
# Borrower1Race1Type                   int64
# Borrower2Race1Type                   int64
# Borrower1GenderType                  int64
# Borrower2GenderType                  int64
# Borrower1AgeAtApplicationYears       int64
# Borrower2AgeAtApplicationYears       int64
# PropertyUsageType                    int64
# PropertyUnitCount                    int64
# NoteRatePercent                    float64
# NoteAmount                           int64
# HousingExpenseRatioPercent         float64
# TotalDebtExpenseRatioPercent       float64
# Borrower1CreditScoreValue            int64
# Borrower2CreditScoreValue            int64
# PMICoveragePercent                 float64
# EmploymentBorrowerSelfEmployed       int64
# PropertyType                        object
# IndexSourceType                      int64
# MarginRatePercent                    int64
# Borrower1EthnicityType               int64
# Borrower1Race2Type                   int64
# Borrower1Race3Type                   int64
# Borrower1Race4Type                   int64
# Borrower1Race5Type                   int64
# Borrower2EthnicityType               int64
# Borrower2Race2Type                   int64
# Borrower2Race3Type                   int64
# Borrower2Race4Type                   int64
# Borrower2Race5Type                   int64
# HOEPALoanStatusType                  int64
# LienPriorityType                     int64
# dtype: object

# %%
#Describe the data
df_2019.describe().transpose()
# Out:
#                                    count          mean            std  \
# Year                             89767.0  2.019000e+03       0.000000
# LoanCharacteristicsID            89767.0  2.452548e+06   26949.017034
# FIPSStateNumericCode             89767.0  2.987412e+01      15.367330
# FIPSCountyCode                   89767.0  8.964927e+01      85.719173
# CoreBasedStatisticalAreaCode     89767.0  3.617272e+04   23931.023618
# CensusTractIdentifier            89767.0  2.681255e+03    3652.664758
# CensusTractMinorityRatioPercent  89767.0  1.784488e+01      18.600936
# CensusTractMedFamIncomeAmount    89767.0  8.779961e+04   30551.702748
# LocalAreaMedianIncomeAmount      89767.0  7.407845e+04   11949.849407
# TotalMonthlyIncomeAmount         89767.0  9.837590e+03    7843.469558
# HUDMedianIncomeAmount            89767.0  7.903644e+04   13119.438254
# LoanAcquisitionActualUPBAmt      89767.0  2.438158e+05  129566.034695
# LTVRatioPercent                  89767.0  7.475098e+01      15.130832
# NoteDate                         89767.0  2.018956e+03       0.226514
# LoanAcquistionDate               89767.0  2.019000e+03       0.000000
# LoanPurposeType                  89767.0  2.743402e+00       2.161045
# ProductCategoryName              89767.0  1.000000e+00       0.000000
# MortgageType                     89767.0  7.676540e-02       0.422898
# ScheduledTotalPaymentCount       89767.0  3.334423e+02      59.921873
# MortgageLoanSellerInstType       89767.0  1.020408e+00       0.403550
# BorrowerCount                    89767.0  1.584034e+00       0.507500
# BorrowerFirstTimeHomebuyer       89767.0  3.561554e-01       0.478865
# Borrower1Race1Type               89767.0  4.915760e+00       0.745901
# Borrower2Race1Type               89767.0  6.242461e+00       1.592354
# Borrower1GenderType              89767.0  1.377009e+00       0.585549
# Borrower2GenderType              89767.0  2.760235e+00       1.127613
# Borrower1AgeAtApplicationYears   89767.0  4.437039e+01      13.328550
# Borrower2AgeAtApplicationYears   89767.0  4.474362e+02     471.482475
# PropertyUsageType                89767.0  1.028095e+00       0.165245
# PropertyUnitCount                89767.0  1.011619e+00       0.126254
# NoteRatePercent                  89767.0  3.965140e+00       0.511299
# NoteAmount                       89767.0  2.440618e+05  129646.820656
# HousingExpenseRatioPercent       89767.0  2.069573e+01       8.956895
# TotalDebtExpenseRatioPercent     89767.0  3.154895e+01       9.561842
# Borrower1CreditScoreValue        89767.0  4.393652e+00       0.826616
# Borrower2CreditScoreValue        89767.0  6.390121e+00       2.314783
# PMICoveragePercent               89767.0  4.529368e+00      10.000697
# EmploymentBorrowerSelfEmployed   89767.0  3.859102e-01       0.486812
# IndexSourceType                  89767.0  9.900000e+01       0.000000
# MarginRatePercent                89767.0  9.366648e+03    2433.738427
# Borrower1EthnicityType           89767.0  2.044916e+00       0.363468
# Borrower1Race2Type               89767.0  6.863045e+00       0.369085
# Borrower1Race3Type               89767.0  6.874230e+00       0.332665
# Borrower1Race4Type               89767.0  6.874653e+00       0.331147
# Borrower1Race5Type               89767.0  6.874676e+00       0.331088
# Borrower2EthnicityType           89767.0  3.302583e+00       1.479171
# Borrower2Race2Type               89767.0  7.347633e+00       0.621057
# Borrower2Race3Type               89767.0  7.352880e+00       0.607281
# Borrower2Race4Type               89767.0  7.353103e+00       0.606711
# Borrower2Race5Type               89767.0  7.353125e+00       0.606661
# HOEPALoanStatusType              89767.0  2.002974e+00       0.056662
# LienPriorityType                 89767.0  1.000000e+00       0.000000
#
#                                         min           25%          50%  \
# Year                                2019.00  2.019000e+03     2019.000
# LoanCharacteristicsID            2406119.00  2.429908e+06  2452349.000
# FIPSStateNumericCode                   1.00  1.800000e+01       27.000
# FIPSCountyCode                         1.00  3.300000e+01       71.000
# CoreBasedStatisticalAreaCode       10100.00  1.943000e+04    31080.000
# CensusTractIdentifier                  1.00  1.020200e+02      414.090
# CensusTractMinorityRatioPercent        0.00  5.390500e+00       11.000
# CensusTractMedFamIncomeAmount          0.00  6.627000e+04    82019.000
# LocalAreaMedianIncomeAmount            0.00  6.582900e+04    73493.000
# TotalMonthlyIncomeAmount             791.00  5.615000e+03     8333.000
# HUDMedianIncomeAmount              38900.00  6.970000e+04    78000.000
# LoanAcquisitionActualUPBAmt        12800.00  1.480000e+05   220000.000
# LTVRatioPercent                        5.00  6.800000e+01       80.000
# NoteDate                            2014.00  2.019000e+03     2019.000
# LoanAcquistionDate                  2019.00  2.019000e+03     2019.000
# LoanPurposeType                        1.00  1.000000e+00        2.000
# ProductCategoryName                    1.00  1.000000e+00        1.000
# MortgageType                           0.00  0.000000e+00        0.000
# ScheduledTotalPaymentCount            60.00  3.600000e+02      360.000
# MortgageLoanSellerInstType             1.00  1.000000e+00        1.000
# BorrowerCount                          1.00  1.000000e+00        2.000
# BorrowerFirstTimeHomebuyer             0.00  0.000000e+00        0.000
# Borrower1Race1Type                     1.00  5.000000e+00        5.000
# Borrower2Race1Type                     1.00  5.000000e+00        5.000
# Borrower1GenderType                    1.00  1.000000e+00        1.000
# Borrower2GenderType                    1.00  2.000000e+00        2.000
# Borrower1AgeAtApplicationYears        18.00  3.400000e+01       42.000
# Borrower2AgeAtApplicationYears        18.00  3.900000e+01       61.000
# PropertyUsageType                      1.00  1.000000e+00        1.000
# PropertyUnitCount                      1.00  1.000000e+00        1.000
# NoteRatePercent                        2.50  3.625000e+00        3.875
# NoteAmount                         12800.00  1.480000e+05   220000.000
# HousingExpenseRatioPercent             0.00  1.476000e+01       19.510
# TotalDebtExpenseRatioPercent           0.27  2.441000e+01       31.820
# Borrower1CreditScoreValue              1.00  4.000000e+00        5.000
# Borrower2CreditScoreValue              1.00  5.000000e+00        5.000
# PMICoveragePercent                     0.00  0.000000e+00        0.000
# EmploymentBorrowerSelfEmployed         0.00  0.000000e+00        0.000
# IndexSourceType                       99.00  9.900000e+01       99.000
# MarginRatePercent                      0.00  9.999000e+03     9999.000
# Borrower1EthnicityType                 1.00  2.000000e+00        2.000
# Borrower1Race2Type                     1.00  7.000000e+00        7.000
# Borrower1Race3Type                     2.00  7.000000e+00        7.000
# Borrower1Race4Type                     5.00  7.000000e+00        7.000
# Borrower1Race5Type                     6.00  7.000000e+00        7.000
# Borrower2EthnicityType                 1.00  2.000000e+00        2.000
# Borrower2Race2Type                     1.00  7.000000e+00        7.000
# Borrower2Race3Type                     3.00  7.000000e+00        7.000
# Borrower2Race4Type                     5.00  7.000000e+00        7.000
# Borrower2Race5Type                     6.00  7.000000e+00        7.000
# HOEPALoanStatusType                    1.00  2.000000e+00        2.000
# LienPriorityType                       1.00  1.000000e+00        1.000
#
#                                          75%          max
# Year                                2019.000     2019.000
# LoanCharacteristicsID            2474790.500  2521673.000
# FIPSStateNumericCode                  42.000       66.000
# FIPSCountyCode                       121.000      840.000
# CoreBasedStatisticalAreaCode       41180.000    99999.000
# CensusTractIdentifier               4922.015     9917.030
# CensusTractMinorityRatioPercent       22.546       99.822
# CensusTractMedFamIncomeAmount     104219.000   250001.000
# LocalAreaMedianIncomeAmount        79347.000   133523.000
# TotalMonthlyIncomeAmount           11907.000   449001.000
# HUDMedianIncomeAmount              86100.000   135500.000
# LoanAcquisitionActualUPBAmt       316214.000  1290000.000
# LTVRatioPercent                       80.000      112.000
# NoteDate                            2019.000     2019.000
# LoanAcquistionDate                  2019.000     2019.000
# LoanPurposeType                        6.000        6.000
# ProductCategoryName                    1.000        1.000
# MortgageType                           0.000        3.000
# ScheduledTotalPaymentCount           360.000      360.000
# MortgageLoanSellerInstType             1.000        9.000
# BorrowerCount                          2.000        5.000
# BorrowerFirstTimeHomebuyer             1.000        1.000
# Borrower1Race1Type                     5.000        6.000
# Borrower2Race1Type                     8.000        8.000
# Borrower1GenderType                    2.000        6.000
# Borrower2GenderType                    4.000        6.000
# Borrower1AgeAtApplicationYears        54.000       98.000
# Borrower2AgeAtApplicationYears       998.000      999.000
# PropertyUsageType                      1.000        2.000
# PropertyUnitCount                      1.000        4.000
# NoteRatePercent                        4.300        6.250
# NoteAmount                        316848.500  1290000.000
# HousingExpenseRatioPercent            25.590      999.000
# TotalDebtExpenseRatioPercent          39.050       78.040
# Borrower1CreditScoreValue              5.000        9.000
# Borrower2CreditScoreValue              9.000        9.000
# PMICoveragePercent                     0.000       78.000
# EmploymentBorrowerSelfEmployed         1.000        1.000
# IndexSourceType                       99.000       99.000
# MarginRatePercent                   9999.000     9999.000
# Borrower1EthnicityType                 2.000        4.000
# Borrower1Race2Type                     7.000        7.000
# Borrower1Race3Type                     7.000        7.000
# Borrower1Race4Type                     7.000        7.000
# Borrower1Race5Type                     7.000        7.000
# Borrower2EthnicityType                 5.000        5.000
# Borrower2Race2Type                     8.000        8.000
# Borrower2Race3Type                     8.000        8.000
# Borrower2Race4Type                     8.000        8.000
# Borrower2Race5Type                     8.000        8.000
# HOEPALoanStatusType                    2.000        3.000
# LienPriorityType                       1.000        1.000

# %% [markdown]
# # Lets work with each columns and visualize any pattern in the data.

# %% [markdown]
# ## Bank : Name of Federal Home Loan Bank District

# %% [markdown]
# Lets check the Bank columns.

# %%
df_2019['Bank'].value_counts()
# Out:
# Chicago          22462
# Topeka           16093
# Des Moines       14468
# Cincinnati       11250
# Dallas            8069
# Indianapolis      5677
# Pittsburgh        4458
# Boston            2824
# San Francisco     2487
# New York          1979
# Name: Bank, dtype: int64

# %%
df_2019['Bank'].hist(ec='Black')
plt.xticks(rotation='vertical')
plt.ylabel('Bank Counts')
plt.show()

# %% [markdown]
# Chicago is having large number of banks,then Topeka.

# %% [markdown]
# ## FIPSStateNumericCode : 2 Digit FIPS State Code
# ## and
# ## FIPSCountyCode: 3 Digit FIPS County Code

# %%
df_2019['FIPSStateNumericCode'].value_counts()
# Out:
# 55    10747
# 17     6843
# 39     6748
# 19     5782
# 20     5004
# 6      4910
# 18     4409
# 48     4409
# 31     4403
# 29     3628
# 27     3471
# 8      2734
# 42     2300
# 26     2197
# 25     2077
# 21     1502
# 46     1451
# 36     1377
# 51     1243
# 40     1197
# 12     1085
# 47      930
# 34      859
# 37      839
# 4       839
# 16      810
# 22      754
# 13      735
# 5       730
# 24      623
# 53      593
# 41      587
# 49      577
# 1       381
# 9       305
# 32      297
# 23      275
# 35      264
# 45      237
# 54      208
# 44      187
# 28      177
# 38      162
# 30      157
# 11      151
# 50      148
# 33      138
# 56      125
# 10       85
# 15       54
# 2        17
# 66        6
# Name: FIPSStateNumericCode, dtype: int64

# %%
#Lets collect the state code from internet
states=pd.read_csv('https://www2.census.gov/geo/docs/reference/state.txt',sep='|')
states.head()
# Out:
#    STATE STUSAB  STATE_NAME  STATENS
# 0      1     AL     Alabama  1779775
# 1      2     AK      Alaska  1785533
# 2      4     AZ     Arizona  1779777
# 3      5     AR    Arkansas    68085
# 4      6     CA  California  1779778

# %%
#Rename FIPSStateNumericCode column to merge with states dataframe
df_2019=df_2019.rename(columns={"FIPSStateNumericCode": "STATE"})

# %%
#Check the column names. 
df_2019.head()
# Out:
#    Year  LoanCharacteristicsID    Bank  STATE  FIPSCountyCode  \
# 0  2019                2407198  Boston     50               7
# 1  2019                2407199  Boston     50               7
# 2  2019                2407200  Boston     50              15
# 3  2019                2407201  Boston     50              17
# 4  2019                2407202  Boston     23              31
#
#    CoreBasedStatisticalAreaCode  CensusTractIdentifier  \
# 0                         15540                   34.0
# 1                         15540                   29.0
# 2                         99999                 9532.0
# 3                         30100                 9594.0
# 4                         38860                  254.0
#
#    CensusTractMinorityRatioPercent  CensusTractMedFamIncomeAmount  \
# 0                            4.577                         132474
# 1                            3.421                         100795
# 2                            6.152                          49625
# 3                            3.935                          62643
# 4                            6.031                          87679
#
#    LocalAreaMedianIncomeAmount  ...  Borrower1Race3Type  Borrower1Race4Type  \
# 0                        84290  ...                   7                   7
# 1                        84290  ...                   7                   7
# 2                        67566  ...                   7                   7
# 3                        67105  ...                   7                   7
# 4                        76445  ...                   7                   7
#
#    Borrower1Race5Type  Borrower2EthnicityType  Borrower2Race2Type  \
# 0                   7                       5                   8
# 1                   7                       2                   7
# 2                   7                       2                   7
# 3                   7                       2                   7
# 4                   7                       5                   8
#
#    Borrower2Race3Type  Borrower2Race4Type  Borrower2Race5Type  \
# 0                   8                   8                   8
# 1                   7                   7                   7
# 2                   7                   7                   7
# 3                   7                   7                   7
# 4                   8                   8                   8
#
#    HOEPALoanStatusType  LienPriorityType
# 0                    2                 1
# 1                    2                 1
# 2                    2                 1
# 3                    2                 1
# 4                    2                 1
#
# [5 rows x 54 columns]

# %%
#Merge two dataframe and replace statecode with statenames. 
df_2019['STATE']=pd.merge(df_2019, states,how="left",on='STATE')['STATE_NAME']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-73fa8ac0f397> in <module>
# ----> 1 df_2019['STATE']=pd.merge(df_2019, states,how="left",on='STATE')['STATE_NAME']
#       2 df_2019['STATE'].value_counts()
#
# D:\Installation\Anaconda\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# D:\Installation\Anaconda\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     654         # validate the merge keys dtypes. We may need to coerce
#     655         # to avoid incompatible dtypes
# --> 656         self._maybe_coerce_merge_keys()
#     657
#     658         # If argument passed to validate,
#
# D:\Installation\Anaconda\lib\site-packages\pandas\core\reshape\merge.py in _maybe_coerce_merge_keys(self)
#    1163                     inferred_right in string_types and inferred_left not in string_types
#    1164                 ):
# -> 1165                     raise ValueError(msg)
#    1166
#    1167             # datetimelikes must match exactly
#
# ValueError: You are trying to merge on object and int64 columns. If you wish to proceed you should use pd.concat

# %%
df_2019['STATE'].value_counts()
# Out:
# Wisconsin               10747
# Illinois                 6843
# Ohio                     6748
# Iowa                     5782
# Kansas                   5004
# California               4910
# Indiana                  4409
# Texas                    4409
# Nebraska                 4403
# Missouri                 3628
# Minnesota                3471
# Colorado                 2734
# Pennsylvania             2300
# Michigan                 2197
# Massachusetts            2077
# Kentucky                 1502
# South Dakota             1451
# New York                 1377
# Virginia                 1243
# Oklahoma                 1197
# Florida                  1085
# Tennessee                 930
# New Jersey                859
# Arizona                   839
# North Carolina            839
# Idaho                     810
# Louisiana                 754
# Georgia                   735
# Arkansas                  730
# Maryland                  623
# Washington                593
# Oregon                    587
# Utah                      577
# Alabama                   381
# Connecticut               305
# Nevada                    297
# Maine                     275
# New Mexico                264
# South Carolina            237
# West Virginia             208
# Rhode Island              187
# Mississippi               177
# North Dakota              162
# Montana                   157
# District of Columbia      151
# Vermont                   148
# New Hampshire             138
# Wyoming                   125
# Delaware                   85
# Hawaii                     54
# Alaska                     17
# Guam                        6
# Name: STATE, dtype: int64

# %% [markdown]
# Therefore Wisconsin have highest number of mortage loans

# %%
#Lets check Counties. 
df_2019['FIPSCountyCode'].value_counts().shape
# Out:
# (219,)

# %%
df_2019['FIPSCountyCode'].hist(bins=219)
plt.show()

# %% [markdown]
# Hence most of the counties between 0 and 200 have highest loan counts

# %% [markdown]
# ## CensusTractMinorityRatioPercent: The percentage of the property's census tract population that is minority.

# %% [markdown]
# Check the minority ratio of the community.

# %%
df_2019['CensusTractMinorityRatioPercent'].hist()
plt.xlabel('Minority Ratio')
plt.show()

# %% [markdown]
# Hence most of the mortages have low Minority ratio.

# %% [markdown]
# ## CensusTractMedFamIncomeAmount : The property's census tract median family income

# %% [markdown]
# Let check median income based on census.

# %%
df_2019['CensusTractMedFamIncomeAmount'].hist(bins=10)
plt.show()

# %%
#Stattiscs of the median income
df_2019['CensusTractMedFamIncomeAmount'].describe()
# Out:
# count     89767.000000
# mean      87799.607785
# std       30551.702748
# min           0.000000
# 25%       66270.000000
# 50%       82019.000000
# 75%      104219.000000
# max      250001.000000
# Name: CensusTractMedFamIncomeAmount, dtype: float64

# %% [markdown]
# ## LocalAreaMedianIncomeAmount : The property's median income for the area based on the most recent decennial census.

# %%
df_2019['LocalAreaMedianIncomeAmount'].hist(bins=10)
plt.show()

# %%
df_2019['LocalAreaMedianIncomeAmount'].describe()
# Out:
# count     89767.000000
# mean      74078.453998
# std       11949.849407
# min           0.000000
# 25%       65829.000000
# 50%       73493.000000
# 75%       79347.000000
# max      133523.000000
# Name: LocalAreaMedianIncomeAmount, dtype: float64

# %% [markdown]
# Hence local area median income seems to be less than countrywise median income

# %% [markdown]
# ## TotalMonthlyIncomeAmount: The total monthly qualifying income used for underwriting in whole dollars for all borrowers on the loan.

# %% [markdown]
# Lets plot the histogram and statiscs to check the overall income used to underwrite loans.

# %%
#lets convert monthly income to annual inocme
df_2019['TotalAnnualIncomeAmount']=df_2019['TotalMonthlyIncomeAmount']*12

# %%
df_2019['TotalAnnualIncomeAmount'].hist(bins=50)
plt.show()

# %%
df_2019['TotalAnnualIncomeAmount'].describe()
# Out:
# count    8.976700e+04
# mean     1.180511e+05
# std      9.412163e+04
# min      9.492000e+03
# 25%      6.738000e+04
# 50%      9.999600e+04
# 75%      1.428840e+05
# max      5.388012e+06
# Name: TotalAnnualIncomeAmount, dtype: float64

# %%
#lets plot boxplot to see if there is any otliers. 
plt.boxplot(df_2019['TotalAnnualIncomeAmount'])
plt.show()

# %%
#Check Annual salaraies greater than 75 percentile. 
np.sum(df_2019['TotalAnnualIncomeAmount']>1.428840e+05)
# Out:
# 22438

# %% [markdown]
# Hence it seems that most of the loans have been sanctioned to high income families.

# %% [markdown]
# ## HUDMedianIncomeAmount: Current median income for a family of four for the area as established by HUD

# %%
df_2019['HUDMedianIncomeAmount'].hist(bins=10)
plt.show()

# %%
#Statiscs
df_2019['HUDMedianIncomeAmount'].describe()
# Out:
# count     89767.000000
# mean      79036.440362
# std       13119.438254
# min       38900.000000
# 25%       69700.000000
# 50%       78000.000000
# 75%       86100.000000
# max      135500.000000
# Name: HUDMedianIncomeAmount, dtype: float64

# %% [markdown]
# HUD median income is approx have same pattern as local area income.

# %% [markdown]
# ## LoanAcquisitionActualUPBAmt: The Amount of unpaid principal balance in whole dollars when acquired by the FHLBank.
